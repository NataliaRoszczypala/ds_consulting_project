# %%
import pandas as pd
from utils.data_preprocessor import DataPreprocessor
from utils.eda import EDA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
data = pd.read_csv('../data/shopping_trends.csv', index_col=0)
data
# Out:
#              Age  Gender  ... Preferred Payment Method Frequency of Purchases
# Customer ID               ...
# 1             55    Male  ...                    Venmo            Fortnightly
# 2             19    Male  ...                     Cash            Fortnightly
# 3             50    Male  ...              Credit Card                 Weekly
# 4             21    Male  ...                   PayPal                 Weekly
# 5             45    Male  ...                   PayPal               Annually
# ...          ...     ...  ...                      ...                    ...
# 3896          40  Female  ...                    Venmo                 Weekly
# 3897          52  Female  ...            Bank Transfer              Bi-Weekly
# 3898          46  Female  ...                    Venmo              Quarterly
# 3899          44  Female  ...                    Venmo                 Weekly
# 3900          52  Female  ...                    Venmo              Quarterly
#
# [3900 rows x 18 columns]

# %%
# Data Preprocessing
preprocessor = DataPreprocessor(data)

# %%
# Handle missing values
# print(data.isnull().any())

# No NA values in the data

# %%
outliers = preprocessor.detect_outliers(method='iqr')
print("Outliers detected using IQR method:\n", outliers.sum())
# Out:
# Outliers detected using IQR method:
#  Age                      0
# Purchase Amount (USD)    0
# Review Rating            0
# Previous Purchases       0
# dtype: int64

# %%
# Get preprocessed data
preprocessed_data = preprocessor.get_preprocessed_data()
preprocessed_data
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
#                   Location Size      Color  Season  Review Rating  \
# Customer ID
# 1                 Kentucky    L       Gray  Winter            3.1
# 2                    Maine    L     Maroon  Winter            3.1
# 3            Massachusetts    S     Maroon  Spring            3.1
# 4             Rhode Island    M     Maroon  Spring            3.5
# 5                   Oregon    M  Turquoise  Spring            2.7
# ...                    ...  ...        ...     ...            ...
# 3896              Virginia    L  Turquoise  Summer            4.2
# 3897                  Iowa    L      White  Spring            4.5
# 3898            New Jersey    L      Green  Spring            2.9
# 3899             Minnesota    S      Brown  Summer            3.8
# 3900            California    M      Beige  Spring            3.1
#
#             Subscription Status Payment Method   Shipping Type  \
# Customer ID
# 1                           Yes    Credit Card         Express
# 2                           Yes  Bank Transfer         Express
# 3                           Yes           Cash   Free Shipping
# 4                           Yes         PayPal    Next Day Air
# 5                           Yes           Cash   Free Shipping
# ...                         ...            ...             ...
# 3896                         No           Cash  2-Day Shipping
# 3897                         No         PayPal    Store Pickup
# 3898                         No    Credit Card        Standard
# 3899                         No         PayPal         Express
# 3900                         No  Bank Transfer    Store Pickup
#
#             Discount Applied Promo Code Used  Previous Purchases  \
# Customer ID
# 1                        Yes             Yes                  14
# 2                        Yes             Yes                   2
# 3                        Yes             Yes                  23
# 4                        Yes             Yes                  49
# 5                        Yes             Yes                  31
# ...                      ...             ...                 ...
# 3896                      No              No                  32
# 3897                      No              No                  41
# 3898                      No              No                  24
# 3899                      No              No                  24
# 3900                      No              No                  33
#
#             Preferred Payment Method Frequency of Purchases
# Customer ID
# 1                              Venmo            Fortnightly
# 2                               Cash            Fortnightly
# 3                        Credit Card                 Weekly
# 4                             PayPal                 Weekly
# 5                             PayPal               Annually
# ...                              ...                    ...
# 3896                           Venmo                 Weekly
# 3897                   Bank Transfer              Bi-Weekly
# 3898                           Venmo              Quarterly
# 3899                           Venmo                 Weekly
# 3900                           Venmo              Quarterly
#
# [3900 rows x 18 columns]

# %%
# EDA
eda = EDA(preprocessed_data)

# %%
categorical_columns = data.select_dtypes(include=['object']).columns

for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    # countplot - changed
    sns.countplot(data = data, x = col)
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
print("Summary Statistics:")
print(eda.summary_statistics())
# Out:
# Summary Statistics:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.068462              59.764359       3.749949           25.351538
# std      15.207589              23.685392       0.716223           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.700000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
eda.correlation_matrix()
print("Correlation Statistics:")
print(eda.correlation_statistics())
# Out:
# Correlation Statistics:
#                             Age  Purchase Amount (USD)  Review Rating  \
# Age                    1.000000              -0.010424      -0.021949
# Purchase Amount (USD) -0.010424               1.000000       0.030776
# Review Rating         -0.021949               0.030776       1.000000
# Previous Purchases     0.040445               0.008063       0.004229
#
#                        Previous Purchases
# Age                              0.040445
# Purchase Amount (USD)            0.008063
# Review Rating                    0.004229
# Previous Purchases               1.000000

# %%
print("Categorical Statistics:")
eda.categorical_statistics()
# Out:
# Categorical Statistics:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status Payment Method  Shipping Type Discount Applied  \
# count                 3900           3900           3900             3900
# unique                   2              6              6                2
# top                     No    Credit Card  Free Shipping               No
# freq                  2847            696            675             2223
#
#        Promo Code Used Preferred Payment Method Frequency of Purchases
# count             3900                     3900                   3900
# unique               2                        6                      7
# top                 No                   PayPal         Every 3 Months
# freq              2223                      677                    584

# %%
print("Categorical Correlations:")
eda.categorical_correlations()
# Out:
# Categorical Correlations:
#                             Gender Item Purchased  Category  Location  \
# Gender                         1.0       0.078855  0.012387  0.109221
# Item Purchased            0.078855            1.0       1.0  0.110355
# Category                  0.012387            1.0       1.0  0.103174
# Location                  0.109221       0.110355  0.103174       1.0
# Size                      0.041185       0.072482  0.027726  0.111185
# Color                     0.056927       0.078978  0.078622  0.108882
# Season                    0.020583        0.08175   0.02604  0.116684
# Subscription Status       0.416578       0.079508  0.018567  0.104285
# Payment Method            0.016915       0.085597  0.039573   0.10614
# Shipping Type             0.056029       0.078237  0.028568  0.106024
# Discount Applied          0.595268       0.090455  0.017543  0.109682
# Promo Code Used           0.595268       0.090455  0.017543  0.109682
# Preferred Payment Method  0.035365       0.075032  0.028196  0.115722
# Frequency of Purchases    0.031736       0.076895  0.031258  0.106307
#
#                               Size     Color    Season Subscription Status  \
# Gender                    0.041185  0.056927  0.020583            0.416578
# Item Purchased            0.072482  0.078978   0.08175            0.079508
# Category                  0.027726  0.078622   0.02604            0.018567
# Location                  0.111185  0.108882  0.116684            0.104285
# Size                           1.0  0.075805  0.026468            0.015409
# Color                     0.075805       1.0  0.074335              0.0701
# Season                    0.026468  0.074335       1.0            0.012646
# Subscription Status       0.015409    0.0701  0.012646                 1.0
# Payment Method            0.030017  0.070336  0.031644            0.025848
# Shipping Type              0.02604   0.08006  0.034715            0.040194
# Discount Applied          0.025465  0.070655  0.028504            0.699619
# Promo Code Used           0.025465  0.070655  0.028504            0.699619
# Preferred Payment Method  0.041043  0.081961  0.043459            0.031455
# Frequency of Purchases    0.035383  0.077726  0.030238            0.031601
#
#                          Payment Method Shipping Type Discount Applied  \
# Gender                         0.016915      0.056029         0.595268
# Item Purchased                 0.085597      0.078237         0.090455
# Category                       0.039573      0.028568         0.017543
# Location                        0.10614      0.106024         0.109682
# Size                           0.030017       0.02604         0.025465
# Color                          0.070336       0.08006         0.070655
# Season                         0.031644      0.034715         0.028504
# Subscription Status            0.025848      0.040194         0.699619
# Payment Method                      1.0      0.031947         0.022231
# Shipping Type                  0.031947           1.0         0.033087
# Discount Applied               0.022231      0.033087              1.0
# Promo Code Used                0.022231      0.033087         0.999477
# Preferred Payment Method       0.035994      0.031221         0.032649
# Frequency of Purchases          0.04297      0.040033         0.023804
#
#                          Promo Code Used Preferred Payment Method  \
# Gender                          0.595268                 0.035365
# Item Purchased                  0.090455                 0.075032
# Category                        0.017543                 0.028196
# Location                        0.109682                 0.115722
# Size                            0.025465                 0.041043
# Color                           0.070655                 0.081961
# Season                          0.028504                 0.043459
# Subscription Status             0.699619                 0.031455
# Payment Method                  0.022231                 0.035994
# Shipping Type                   0.033087                 0.031221
# Discount Applied                0.999477                 0.032649
# Promo Code Used                      1.0                 0.032649
# Preferred Payment Method        0.032649                      1.0
# Frequency of Purchases          0.023804                 0.042056
#
#                          Frequency of Purchases
# Gender                                 0.031736
# Item Purchased                         0.076895
# Category                               0.031258
# Location                               0.106307
# Size                                   0.035383
# Color                                  0.077726
# Season                                 0.030238
# Subscription Status                    0.031601
# Payment Method                          0.04297
# Shipping Type                          0.040033
# Discount Applied                       0.023804
# Promo Code Used                        0.023804
# Preferred Payment Method               0.042056
# Frequency of Purchases                      1.0

# %%
#Based on the correlation analysis it can be observed that variables 'Discount Applied' and 'Promo Code Used' as well as 'Item Purchased' and 'Category' are highly correlated, thus we decided to remove variables 'Promo Code Used' and 'Item Purchased' not to include collinearity in the estimation.
preprocessed_data = preprocessed_data.drop(columns=['Promo Code Used', 'Item Purchased'])
preprocessed_data
# Out:
#              Age  Gender     Category  Purchase Amount (USD)       Location  \
# Customer ID
# 1             55    Male     Clothing                     53       Kentucky
# 2             19    Male     Clothing                     64          Maine
# 3             50    Male     Clothing                     73  Massachusetts
# 4             21    Male     Footwear                     90   Rhode Island
# 5             45    Male     Clothing                     49         Oregon
# ...          ...     ...          ...                    ...            ...
# 3896          40  Female     Clothing                     28       Virginia
# 3897          52  Female  Accessories                     49           Iowa
# 3898          46  Female  Accessories                     33     New Jersey
# 3899          44  Female     Footwear                     77      Minnesota
# 3900          52  Female  Accessories                     81     California
#
#             Size      Color  Season  Review Rating Subscription Status  \
# Customer ID
# 1              L       Gray  Winter            3.1                 Yes
# 2              L     Maroon  Winter            3.1                 Yes
# 3              S     Maroon  Spring            3.1                 Yes
# 4              M     Maroon  Spring            3.5                 Yes
# 5              M  Turquoise  Spring            2.7                 Yes
# ...          ...        ...     ...            ...                 ...
# 3896           L  Turquoise  Summer            4.2                  No
# 3897           L      White  Spring            4.5                  No
# 3898           L      Green  Spring            2.9                  No
# 3899           S      Brown  Summer            3.8                  No
# 3900           M      Beige  Spring            3.1                  No
#
#             Payment Method   Shipping Type Discount Applied  \
# Customer ID
# 1              Credit Card         Express              Yes
# 2            Bank Transfer         Express              Yes
# 3                     Cash   Free Shipping              Yes
# 4                   PayPal    Next Day Air              Yes
# 5                     Cash   Free Shipping              Yes
# ...                    ...             ...              ...
# 3896                  Cash  2-Day Shipping               No
# 3897                PayPal    Store Pickup               No
# 3898           Credit Card        Standard               No
# 3899                PayPal         Express               No
# 3900         Bank Transfer    Store Pickup               No
#
#              Previous Purchases Preferred Payment Method  \
# Customer ID
# 1                            14                    Venmo
# 2                             2                     Cash
# 3                            23              Credit Card
# 4                            49                   PayPal
# 5                            31                   PayPal
# ...                         ...                      ...
# 3896                         32                    Venmo
# 3897                         41            Bank Transfer
# 3898                         24                    Venmo
# 3899                         24                    Venmo
# 3900                         33                    Venmo
#
#             Frequency of Purchases
# Customer ID
# 1                      Fortnightly
# 2                      Fortnightly
# 3                           Weekly
# 4                           Weekly
# 5                         Annually
# ...                            ...
# 3896                        Weekly
# 3897                     Bi-Weekly
# 3898                     Quarterly
# 3899                        Weekly
# 3900                     Quarterly
#
# [3900 rows x 16 columns]
